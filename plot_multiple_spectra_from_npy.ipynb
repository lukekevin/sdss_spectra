# %%
import matplotlib.pyplot as plt
import numpy as np
from astropy import units as u
from specutils import Spectrum1D
from astropy.io import fits

# %%
spec_file=np.load("multiple_spectra_with_oh_lines.npy")

# %%
spec_file.shape
# Out:
# (5, 3751)

# %%
fig, ax= plt.subplots(nrows=5, ncols=1, figsize=(15,15))

[i.set_ylabel("Flux") for i in ax]
ax[0].plot(spec_file[0,2500:3000])
ax[1].plot(spec_file[1,2500:3000])
ax[2].plot(spec_file[2,2500:3000])
ax[3].plot(spec_file[3,2500:3000])
ax[4].plot(spec_file[4,25:])
ax[4].set_xlabel("Wavelenghts")
fig.savefig("multiple_spectra_with_oh_lines.jpg")
